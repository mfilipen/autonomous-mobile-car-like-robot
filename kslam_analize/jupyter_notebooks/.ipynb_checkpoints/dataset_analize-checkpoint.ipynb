# %%
import rosbag
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # GroundTruth

# %%
dx = 0.045
markup_x = np.array([0, 4.88, 4.88, 0, 0])
markup_x[:] = markup_x[:] + dx
markup_y = np.array([0, 0, -9.11, -9.11, 0])

plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(markup_x,markup_y, label= "Map landmarks")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend()
plt.show()

# %% [markdown]
# # Hector SLAM

# %%
dataset_path = './../datasets/'
hector_path = dataset_path + 'hector/2018-04-13-15-30-49.bag'
print(hector_path)
# Out:
# ./../datasets/hector/2018-04-13-15-30-49.bag

# %%
def getInfoAboutBag(bag_path):
    bag = rosbag.Bag(bag_path)
    topics = bag.get_type_and_topic_info()[1].keys()
    types = []
    for i in range(0,len(bag.get_type_and_topic_info()[1].values())):
        types.append(bag.get_type_and_topic_info()[1].values()[i][0])

    print(topics)
    print(types)

# %%
getInfoAboutBag(hector_path)
# Out:
# ['/slam_out_pose']
# ['geometry_msgs/PoseStamped']

# %%
bag = rosbag.Bag(hector_path)
hectorPoses = []
for topic, msg, t in bag.read_messages(topics=['/slam_out_pose']):
    hectorPoses.append(msg)
bag.close()

# %%
print(np.shape(hectorPoses))
# Out:
# (7513,)

# %%
cartographerPoseX = []
cartographerPoseY = []

for marker in cartographerPoses[8766].markers:
    for point in marker.points:
        cartographerPoseX.append(point.x)
        cartographerPoseY.append(point.y)

# %%
def getTime(msg):
    stamp = msg.header.stamp
    (sec,nsec)=(stamp.secs,stamp.nsecs)
    time = 1./1000000000 * nsec + sec
    return time

shift=0
def timeShift(time, shift):
    t = time[:] - shift
    return t

# %%
from geometry_msgs.msg import PoseStamped

hector_x = []
hector_y = []
hector_t = []
for poseStamped in hectorPoses:
    hector_x.append(poseStamped.pose.position.x)
    hector_y.append(poseStamped.pose.position.y)
    hector_t.append(getTime(poseStamped))

print(hector_t[0])
hector_x = np.array(hector_x)
hector_y = np.array(hector_y )
hector_t_glob = np.array(hector_t)

hector_t = timeShift(hector_t_glob, hector_t[0])
# Out:
# 1523130805.68

# %%
plt.plot(hector_t, hector_x)
plt.plot(hector_t, hector_y);

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(markup_x,markup_y, label= "Map landmarks")
plt.plot(hector_x, hector_y, label= "Hector_SLAM_pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend()
plt.show()

# %% [markdown]
# # Google Cartographer

# %%
dataset_path = './../datasets/'
cartographer_path = dataset_path + 'cartographer/2018-04-29-20-36-22.bag'
print(hector_path)
# Out:
# ./../datasets/hector/2018-04-13-15-30-49.bag

# %%
getInfoAboutBag(cartographer_path)
# Out:
# ['/constraint_list', '/submap_list', '/scan_matched_points2', '/tf', '/tf_static', '/clock', '/scan', '/map', '/trajectory_node_list']
# ['visualization_msgs/MarkerArray', 'cartographer_ros_msgs/SubmapList', 'sensor_msgs/PointCloud2', 'tf2_msgs/TFMessage', 'tf2_msgs/TFMessage', 'rosgraph_msgs/Clock', 'sensor_msgs/LaserScan', 'nav_msgs/OccupancyGrid', 'visualization_msgs/MarkerArray']

# %%
bag = rosbag.Bag(cartographer_path)
cartographerPoses = []
for topic, msg, t in bag.read_messages(topics=['/trajectory_node_list']):
    cartographerPoses.append(msg)
bag.close()

# %%
print(np.shape(cartographerPoses))
# Out:
# (8767,)

# %%
cartographerPoseX = []
cartographerPoseY = []

for marker in cartographerPoses[8766].markers:
    for point in marker.points:
        cartographerPoseX.append(point.x)
        cartographerPoseY.append(point.y)

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(markup_x,markup_y, label= "Map landmarks")
plt.plot(cartographerPoseX,cartographerPoseY, label= "Google Cartographer pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(hector_x, hector_y, label= "Hector SLAM pose")
plt.plot(cartographerPoseX,cartographerPoseY, label= "Google Cartographer pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %% [markdown]
# # ORB

# %%
orb_path = dataset_path + 'orb/KeyFrameTrajectory.txt'
print(orb_path)
# Out:
# ./../datasets/orb/KeyFrameTrajectory.txt

# %%
orb = np.loadtxt(orb_path)
np.shape(orb)
# Out:
# (180, 8)

# %%
orb_x = orb[:,3]
orb_y = orb[:,1]
orb_t_glob = orb[:,0]

orb_t = timeShift(orb_t_glob, hector_t_glob[0])
orb_y = orb_y * -1

# %%
plot(orb_t, orb_x, orb_t, orb_y, hector_t, hector_x, hector_t, hector_y, colors=colors);

# %%
def getScale(x, X):
    return np.amax(np.abs(X))/np.amax(np.abs(x))

# %%
orb_shift_x = orb_x[:] + 0.33
orb_scale_x = orb_shift_x[:] * getScale(orb_shift_x, hector_x)
orb_scale_y =  orb_y[:] * getScale(orb_y, hector_y)

# %%
plot(orb_t, orb_scale_x, orb_t, orb_scale_y, hector_t, hector_x, hector_t, hector_y, colors=colors);

# %%
plot(orb_scale_x, orb_scale_y, colors=colors);

# %%
plot(orb_scale_x, orb_scale_y, hector_x, hector_y, colors=colors);

# %% [markdown]
# # LSD

# %%
lsd_path = dataset_path + 'lsd/lsd.bag'
print(lsd_path)
# Out:
# ./../datasets/lsd/lsd.bag

# %%
getInfoAboutBag(lsd_path)
# Out:
# ['/lsd_slam/graph', '/LSD_SLAM/parameter_updates', '/lsd_slam/keyframes', '/lsd_slam/pose', '/LSD_SLAM/parameter_descriptions', '/lsd_slam/liveframes', '/LSD_SLAM/Debug/parameter_descriptions', '/LSD_SLAM/Debug/parameter_updates']
# ['lsd_slam_viewer/keyframeGraphMsg', 'dynamic_reconfigure/Config', 'lsd_slam_viewer/keyframeMsg', 'geometry_msgs/PoseStamped', 'dynamic_reconfigure/ConfigDescription', 'lsd_slam_viewer/keyframeMsg', 'dynamic_reconfigure/ConfigDescription', 'dynamic_reconfigure/Config']

# %%
bag = rosbag.Bag(lsd_path)
lsdPoses = []
for topic, msg, t in bag.read_messages(topics=['/lsd_slam/pose']):
    lsdPoses.append(msg)
bag.close()

# %%
from geometry_msgs.msg import PoseStamped

lsd_x_glob = []
lsd_y_glob = []
lsd_t_glob = []
for poseStamped in lsdPoses:
    lsd_x_glob.append(poseStamped.pose.position.z)
    lsd_y_glob.append(poseStamped.pose.position.x)
    lsd_t_glob.append(getTime(poseStamped))

lsd_x_glob = np.array(lsd_x_glob)
lsd_y_glob = np.array(lsd_y_glob)
lsd_t_glob = np.array(lsd_t_glob)

lsd_y_glob = lsd_y_glob[:] * -1

lsd_t_ = timeShift(lsd_t_glob, hector_t_glob[0])

# %%
n = 700
lsd_x_glob_ = lsd_x_glob[n:]
lsd_y_glob_ = lsd_y_glob[n:]
lsd_t_glob_ = lsd_t_glob[n:]
lsd_t = lsd_t_[n:]

alpha = - 0.40

lsd_x =  np.cos(alpha) * lsd_x_glob_ + np.sin(alpha) * lsd_y_glob_
lsd_y = -np.sin(alpha) * lsd_x_glob_ + np.cos(alpha) * lsd_y_glob_

# %%
plot(lsd_t, lsd_x, lsd_t, lsd_y, colors=colors);

# %%
plot(lsd_x, lsd_y, colors=colors);

# %%
plot(lsd_t, lsd_x, lsd_t, lsd_y, hector_t, hector_x, hector_t, hector_y, colors=colors);

# %%
lsd_shift_x = lsd_x[:] - 0.35 
lsd_scale_x = lsd_shift_x[:] * getScale(lsd_shift_x, hector_x)  
lsd_shift_y = lsd_y[:] - 0.445
lsd_scale_y =  lsd_shift_y [:] * getScale(lsd_shift_y , hector_y)

# %%
plot(lsd_t, lsd_scale_x, lsd_t, lsd_scale_y, hector_t, hector_x, hector_t, hector_y, colors=colors);

# %%
plot(lsd_scale_x, lsd_scale_y, hector_x, hector_y,colors=colors);

# %% [markdown]
# # DSO

# %%
dso_path = dataset_path + 'dso/result0.6.txt'
print(lsd_path)
# Out:
# ./../datasets/lsd/lsd.bag

# %%
dso = np.loadtxt(dso_path)
np.shape(dso)
# Out:
# (367, 8)

# %%
n = 10
dso_x_glob = dso[n:,3]
dso_y_glob = dso[n:,1]
dso_t_glob = dso[n:,0]

dso_t = timeShift(dso_t_glob, hector_t_glob[0])
dso_y_glob = dso_y_glob * -1

alpha = 0.10

dso_x =  np.cos(alpha) * dso_x_glob + np.sin(alpha) * dso_y_glob
dso_y = -np.sin(alpha) * dso_x_glob + np.cos(alpha) * dso_y_glob

# %%
plot(dso_x, dso_y, colors=colors);

# %%
plot(dso_t, dso_x, dso_t, dso_y, hector_t, hector_x, hector_t, hector_y, colors=colors);

# %%
dso_shift_x = dso_x[:] 
dso_scale_x = dso_shift_x[:] * getScale(dso_shift_x, hector_x)
dso_shift_y = dso_y[:] - 0.045
dso_scale_y = dso_shift_y[:] * getScale(dso_shift_y, hector_y)

# %%
plot(dso_t, dso_scale_x, dso_t, dso_scale_y, hector_t, hector_x, hector_t, hector_y, colors=colors);

# %%
plot(dso_scale_x, dso_scale_y, hector_x, hector_y, colors=colors);

# %% [markdown]
# # DPPTAM

# %%
dpptam_path = dataset_path + 'dpptam/2018-04-12-21-47-49.bag'
print(dpptam_path)
# Out:
# ./../datasets/dpptam/2018-04-12-21-47-49.bag

# %%
getInfoAboutBag(dpptam_path)
# Out:
# ['/tf']
# ['tf2_msgs/TFMessage']

# %%
bag = rosbag.Bag(dpptam_path)
dpptam_tf = []
for topic, msg, t in bag.read_messages(topics=['/tf']):
    dpptam_tf.append(msg)
bag.close()

# %%
dpptam_tf
# Out:
# [transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130805
#          nsecs: 950011035
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 0.0
#          y: 0.0
#          z: 0.0
#        rotation:
#          x: 0.0
#          y: 0.0
#          z: 0.0
#          w: 1.0, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130805
#          nsecs: 990223443
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 7.30259587667e-06
#          y: 1.04841344188e-05
#          z: 2.59417369934e-05
#        rotation:
#          x: -8.72127563112e-06
#          y: 3.40592613135e-06
#          z: -5.0519098122e-06
#          w: 0.999999999943, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs:  35604534
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 5.13820522426e-06
#          y: -1.64790918167e-05
#          z: 1.1410989457e-05
#        rotation:
#          x: 8.85132701669e-06
#          y: 5.55955642496e-06
#          z: 2.1396385708e-06
#          w: 0.999999999943, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs:  91008193
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 4.24410317783e-06
#          y: 1.69395071902e-05
#          z: 2.51685421411e-05
#        rotation:
#          x: -1.24568037782e-05
#          y: 4.81359186994e-06
#          z: 8.61970922124e-06
#          w: 0.999999999874, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 131609776
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -4.96715752018e-06
#          y: 2.64601353161e-05
#          z: 2.24888858648e-05
#        rotation:
#          x: -1.60520931124e-05
#          y: -7.46534162567e-07
#          z: -3.92418655078e-06
#          w: 0.999999999863, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 172446664
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 2.78305034584e-05
#          y: -2.4431364091e-05
#          z: 4.18823091618e-05
#        rotation:
#          x: 7.33704396393e-06
#          y: 1.41853588869e-05
#          z: -1.13633648668e-05
#          w: 0.999999999808, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 218301541
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 3.33154288877e-06
#          y: -3.30869833303e-05
#          z: -3.26616014692e-06
#        rotation:
#          x: 1.40989433981e-05
#          y: 1.86452483303e-06
#          z: 1.12863149952e-05
#          w: 0.999999999835, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 258677276
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 4.18279090628e-05
#          y: -2.16480016321e-05
#          z: 2.33170667915e-05
#        rotation:
#          x: 9.42967038245e-06
#          y: 2.22744943124e-05
#          z: 2.32583000452e-06
#          w: 0.999999999705, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 310011828
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 5.01733938289e-05
#          y: -1.51224911167e-05
#          z: 2.72574304503e-05
#        rotation:
#          x: 1.29296828179e-06
#          y: 2.14993142801e-05
#          z: -2.17507660372e-06
#          w: 0.999999999766, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 350542685
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -3.19076486911e-06
#          y: -3.71086812753e-06
#          z: 2.01425717328e-05
#        rotation:
#          x: -4.16856071918e-06
#          y: -2.34385074284e-06
#          z: -2.98252329488e-06
#          w: 0.999999999984, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 396125149
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 2.8495362079e-05
#          y: 2.44105012927e-05
#          z: 2.68374099499e-05
#        rotation:
#          x: -1.22157406031e-05
#          y: 1.49225666016e-05
#          z: -5.51497225785e-08
#          w: 0.999999999814, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 441504213
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: 1.59091549378e-05
#          y: 2.67734773513e-05
#          z: 3.03062586131e-05
#        rotation:
#          x: -1.59172535837e-05
#          y: 1.14013024907e-05
#          z: 2.48675865562e-06
#          w: 0.999999999805, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130806
#          nsecs: 482122083
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x:
transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs:  32482266
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0705463744288
#          y: 0.022917633753
#          z: -0.952904912785
#        rotation:
#          x: -0.00573565523276
#          y: 0.16139604294
#          z: -0.0465333562549
#          w: 0.98577536302, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs:  73038955
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0708945147934
#          y: 0.0233954967355
#          z: -0.954351680478
#        rotation:
#          x: -0.00653809539783
#          y: 0.16142299919
#          z: -0.0454490349324
#          w: 0.985816541688, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 113547127
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0720894996079
#          y: 0.0238591883473
#          z: -0.956611422106
#        rotation:
#          x: -0.0070379493012
#          y: 0.161608399637
#          z: -0.0451407126537
#          w: 0.985796890083, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 159015654
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.073349410129
#          y: 0.0246630741778
#          z: -0.959168636205
#        rotation:
#          x: -0.00762095374171
#          y: 0.162119120222
#          z: -0.0444543614166
#          w: 0.985739885403, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 201423723
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0745389638569
#          y: 0.0254266802547
#          z: -0.961586492823
#        rotation:
#          x: -0.00824033187652
#          y: 0.162493476187
#          z: -0.0436089148356
#          w: 0.985711027469, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 246676181
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0753202374111
#          y: 0.0255280274735
#          z: -0.963644318041
#        rotation:
#          x: -0.00840453780371
#          y: 0.162736078481
#          z: -0.0438074532867
#          w: 0.985660813638, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 312467751
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0767546670605
#          y: 0.025834952378
#          z: -0.966270046631
#        rotation:
#          x: -0.00870572038395
#          y: 0.16303367666
#          z: -0.0439203656887
#          w: 0.985603993592, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 353346975
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0782294583837
#          y: 0.0262519594623
#          z: -0.969013881974
#        rotation:
#          x: -0.0089343097577
#          y: 0.1632919211
#          z: -0.0439418271942
#          w: 0.985558238987, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 388601610
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0797118325768
#          y: 0.0266759802547
#          z: -0.97175993268
#        rotation:
#          x: -0.00896984812975
#          y: 0.16407337566
#          z: -0.0440508027364
#          w: 0.985423257287, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 423798701
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0809751172002
#          y: 0.0270860474844
#          z: -0.974354874121
#        rotation:
#          x: -0.00918773168469
#          y: 0.165024454292
#          z: -0.0438067581909
#          w: 0.985273303713, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 469248439
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.082205411788
#          y: 0.0274877183669
#          z: -0.976784681758
#        rotation:
#          x: -0.00918342311236
#          y: 0.16620858484
#          z: -0.0433365182214
#          w: 0.985095080311, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 509528454
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0834235589557
#          y: 0.0278485777515
#          z: -0.979242782364
#        rotation:
#          x: -0.00952510820443
#          y: 0.167480539585
#          z: -0.0432637647636
#          w: 0.984879580371, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 554830874
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0845583852819
#          y: 0.0281375570462
#          z: -0.981589825029
#        rotation:
#          x: -0.0095129482684
#          y: 0.168806210502
#          z: -0.0428305845392
#          w: 0.98467228464, transforms:
#    -
#      header:
#        seq: 0
#        stamp:
#          secs: 1523130850
#          nsecs: 600141308
#        frame_id: dpptam/map
#      child_frame_id: dpptam/visualization_marker
#      transform:
#        translation:
#          x: -0.0857626867683
#          y: 0.0284871264833
#          z: -0.983927020178
#        rotation:
#          x: -0.00978205190171
#          y: 0.170107648889
#          z: -0.0423082378928
#          w: 0.984468238318, ...]

# %%
from tf2_msgs.msg  import TFMessage
import tf2_ros

ddptam_tf = []

for tf in dpptam_tf:
    msg=tf.transforms[0]
    if (msg.child_frame_id == 'dpptam/visualization_marker'):
        ddptam_tf.append(msg.transform)
