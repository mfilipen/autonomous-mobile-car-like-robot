# %%
import rosbag
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

width = 3.487
height = width / 1.618

import matplotlib.image as mpimg

plt.rc('font', family='serif', serif='Times')
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=8)
plt.rc('axes', labelsize=8)
plt.rc('text', usetex='true')


plt.rcParams['pdf.fonttype'] = 42

# %%
from scipy.interpolate import interp1d

def ate(x1,y1,t1,x2,y2,t2,folder): 
    fx = interp1d(t1, x1)
    fy = interp1d(t1, y1)
    
    x = fx(t2) - x2
    y = fy(t2) - y2
    
    r = np.sqrt(x**2 + y**2)
    
    rmse = np.sqrt(np.mean(r ** 2))
    
    rmin = np.amin(r)
    rmax = np.amax(r)
    median = np.median(r)
    mean = np.mean(r)
    std = np.std(r)
    var = np.var(r)
    
    print ("RMSE: ", rmse)
    print ("min: ", rmin)
    print ("max: ", rmax)
    print ("median: ", median)
    print ("mean: ", mean)
    print ("std: ", std)
    print ("var: ", var)
    
    plt.figure(figsize=(width,width))
    plt.title("Absolute trajectory error")
    plt.plot(t2,x, label= "x error")
    plt.plot(t2,y, label= "y error")
    plt.plot(t2,r, label= "ATE")
    
    
    plt.grid(linestyle='dotted')
    plt.xlabel("Position x (m)", fontsize=12)
    plt.ylabel("Position y (m)", fontsize=12)
    plt.legend(loc ='best', fontsize = 8, framealpha=1)
    plt.savefig('./images/' +folder, bbox_inches='tight', format='png', dpi=600)
    plt.show()

# %% [markdown]
# # GroundTruth

# %%
dx = 0.045
markup_x = np.array([0, 4.88, 4.88, 0, 0])
markup_x[:] = markup_x[:] + dx
markup_y = np.array([0, 0, -9.11, -9.11, 0])

plt.figure(figsize=(5,5))
plt.title("Test environment")
plt.plot(markup_x,markup_y, label= "Map landmarks")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend()
plt.show()

# %% [markdown]
# # Hector SLAM

# %%
dataset_path = './../datasets/'
hector_path = dataset_path + 'zed/hector_slam/2018-05-01-00-46-12.bag'
print(hector_path)
# Out:
# ./../datasets/zed/hector_slam/2018-05-01-00-46-12.bag

# %%
def getInfoAboutBag(bag_path):
    bag = rosbag.Bag(bag_path)
    topics = bag.get_type_and_topic_info()[1].keys()
    types = []
    for i in range(0,len(bag.get_type_and_topic_info()[1].values())):
        types.append(bag.get_type_and_topic_info()[1].values()[i][0])

    print(topics)
    print(types)

# %%
getInfoAboutBag(hector_path)
# Out:
# ['/slam_out_pose']
# ['geometry_msgs/PoseStamped']

# %%
bag = rosbag.Bag(hector_path)
hectorPoses = []
for topic, msg, t in bag.read_messages(topics=['/slam_out_pose']):
    hectorPoses.append(msg)
bag.close()

# %%
print(np.shape(hectorPoses))
# Out:
# (7580,)

# %%
def getTime(msg):
    stamp = msg.header.stamp
    (sec,nsec)=(stamp.secs,stamp.nsecs)
    time = 1./1000000000 * nsec + sec
    return time

shift=0
def timeShift(time, shift):
    t = time[:] - shift
    return t

# %%
from geometry_msgs.msg import PoseStamped

hector_x = []
hector_y = []
hector_t = []
for poseStamped in hectorPoses:
    hector_x.append(poseStamped.pose.position.x)
    hector_y.append(poseStamped.pose.position.y)
    hector_t.append(getTime(poseStamped))

print(hector_t[0])
hector_x = np.array(hector_x)
hector_y = np.array(hector_y )
hector_t_glob = np.array(hector_t)
start_time = hector_t[0]
hector_t = timeShift(hector_t_glob, start_time)
# Out:
# 1523130541.12

# %%
plt.plot(hector_t, hector_x)
plt.plot(hector_t, hector_y);

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(markup_x,markup_y, label= "Map landmarks")
plt.plot(hector_x, hector_y, label= "Hector SLAM trajectory")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %% [markdown]
# # ZEDfu

# %%
import rospkg
rospack = rospkg.RosPack()
zedfu_path= rospack.get_path('carlike') + '/datasets/2018-04-07-22-49-00.bag'
print(zedfu_path)
# Out:
# /home/maksim/mfilipenko_ws/src/carlike/datasets/2018-04-07-22-49-00.bag

# %%
getInfoAboutBag(zedfu_path)
# Out:
# ['/imu_node/parameter_updates', '/zed/odom', '/hokuyo/parameter_descriptions', '/zed/left/image_raw_color/compressed', '/zed/right/image_raw_color/compressed', '/hokuyo/parameter_updates', '/tf_static', '/imu_node/parameter_descriptions', '/tf', '/joy', '/scan', '/drivecmd', '/diagnostics']
# ['dynamic_reconfigure/Config', 'nav_msgs/Odometry', 'dynamic_reconfigure/ConfigDescription', 'sensor_msgs/CompressedImage', 'sensor_msgs/CompressedImage', 'dynamic_reconfigure/Config', 'tf2_msgs/TFMessage', 'dynamic_reconfigure/ConfigDescription', 'tf2_msgs/TFMessage', 'sensor_msgs/Joy', 'sensor_msgs/LaserScan', 'ackermann_msgs/AckermannDrive', 'diagnostic_msgs/DiagnosticArray']

# %%
bag = rosbag.Bag(zedfu_path)
zedfu_poses = []
for topic, msg, t in bag.read_messages(topics=['/zed/odom']):
    zedfu_poses.append(msg)
bag.close()

# %%
print(np.shape(zedfu_poses))
# Out:
# (1257,)

# %%
zedfu_x = []
zedfu_y = []
zedfu_t = []

for odom in zedfu_poses:
    zedfu_x.append(odom.pose.pose.position.x)
    zedfu_y.append(odom.pose.pose.position.y)
    zedfu_t.append(getTime(odom))

    
zedfu_t_glob = np.array(zedfu_t)
zedfu_t = timeShift(zedfu_t_glob, start_time)

# %%
np.shape(zedfu_t)
# Out:
# (1257,)

# %%
zedfu_t = np.delete(zedfu_t,0)
zedfu_x = np.delete(zedfu_x,0)
zedfu_y = np.delete(zedfu_y,0)

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(markup_x,markup_y, label= "Map landmarks")
plt.plot(zedfu_x,zedfu_y, label= "ZEDfu pose")
plt.plot(hector_x, hector_y, label= "Hector SLAM_pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(zedfu_t, zedfu_x, label= "ORB SLAM pose X")
plt.plot(zedfu_t, zedfu_y, label= "ORB SLAM pose Y")
plt.plot(hector_t, hector_x, label= "Hector SLAM pose X")
plt.plot(hector_t, hector_y, label= "Hector SLAM pose Y");
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
plt.figure(figsize=(width+1,width+1))
plt.title("Robot trajectory")
plt.plot(zedfu_x,zedfu_y, label= "ZEDfu \n trajectory")
plt.plot(hector_x, hector_y, label= "Hector SLAM \n trajectory")
plt.axis('equal')
plt.grid(linestyle='dotted')
plt.xlabel("Position x (m)", fontsize=14)
plt.ylabel("Position y (m)", fontsize=14)
plt.legend(loc =10, fontsize = 8, framealpha=1)
plt.savefig('./images/zed/zedfu.png', bbox_inches='tight', format='png', dpi=600)
plt.show()

# %%
ate(hector_x, hector_y,hector_t,zedfu_x,zedfu_y,zedfu_t, "zed/ateZedHect.png")
# Out:
# ('RMSE: ', 0.7263619893651961)
# ('min: ', 0.002340257415670651)
# ('max: ', 1.3230142130432163)
# ('median: ', 0.6926983880630169)
# ('mean: ', 0.6317407300377537)
# ('std: ', 0.35847648403477067)
# ('var: ', 0.1285053896059312)

# %% [markdown]
# # ORB

# %%
orb_path = dataset_path + 'zed/orb/video/FrameTrajectory_TUM_Format.txt'
print(orb_path)
# Out:
# ./../datasets/zed/orb/video/FrameTrajectory_TUM_Format.txt

# %%
orb = np.loadtxt(orb_path)
np.shape(orb)
# Out:
# (1255, 8)

# %%
orb_x = orb[:,3]
orb_y = orb[:,1]
orb_t_glob = orb[:,0]

orb_x = orb_x + 0.355
orb_t = timeShift(orb_t_glob, hector_t_glob[0])
orb_y = orb_y * -1

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(markup_x,markup_y, label= "Map landmarks")
plt.plot(orb_x,orb_y, label= "ORB SLAM pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(hector_x, hector_y, label= "Hector SLAM pose")
plt.plot(orb_x,orb_y, label= "ORB SLAM pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
plt.figure(figsize=(width,width))
plt.title("Robot trajectory")
plt.plot(orb_x,orb_y, label= "ORB SLAM \n trajectory")
plt.plot(hector_x, hector_y, label= "Hector SLAM \n trajectory")
plt.axis('equal')
plt.grid(linestyle='dotted')
plt.xlabel("Position x (m)", fontsize=12)
plt.ylabel("Position y (m)", fontsize=12)
plt.legend(loc =10, fontsize = 8, framealpha=1)
plt.savefig('./images/zed/orbslam.png', bbox_inches='tight', format='png', dpi=600)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(orb_t, orb_x, label= "ORB SLAM pose X")
plt.plot(orb_t, orb_y, label= "ORB SLAM pose Y")
plt.plot(hector_t, hector_x, label= "Hector SLAM pose X")
plt.plot(hector_t, hector_y, label= "Hector SLAM pose Y");
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
ate(hector_x, hector_y,hector_t,orb_x,orb_y,orb_t, "zed/ateorbHect.png")
# Out:
# ('RMSE: ', 0.19051542937865357)
# ('min: ', 0.00426203299355153)
# ('max: ', 0.41452086766005947)
# ('median: ', 0.10285881087978196)
# ('mean: ', 0.1513331814436962)
# ('std: ', 0.11573416533358706)
# ('var: ', 0.013394397025462064)

# %% [markdown]
# # RTAB-map

# %%
import rospkg
rospack = rospkg.RosPack()
rtab_path= dataset_path + '/zed/rtab-map/rtab_map.bag'
print(rtab_path)
# Out:
# ./../datasets//zed/rtab-map/rtab_map.bag

# %%
getInfoAboutBag(rtab_path)
# Out:
# ['/rtabmap/odom']
# ['nav_msgs/Odometry']

# %%
bag = rosbag.Bag(rtab_path)
rtab_poses = []
for topic, msg, t in bag.read_messages(topics=['/rtabmap/odom']):
    rtab_poses.append(msg)
bag.close()

# %%
print(np.shape(rtab_poses))
# Out:
# (1113,)

# %%
rtab_x = []
rtab_y = []
rtab_t = []

for odom in rtab_poses:
    rtab_x.append(odom.pose.pose.position.z)
    rtab_y.append(-1 * odom.pose.pose.position.x)
    rtab_t.append(getTime(odom))

# %%
rtab_t_glob = np.array(rtab_t)
rtab_t = timeShift(rtab_t_glob, start_time)

# %%
rtab_x_filtred = []
rtab_y_filtred = []
rtab_t_filtred = []

for i in range(len(rtab_x)):
    if rtab_x[i]!=0:
        rtab_x_filtred.append(rtab_x[i])
        rtab_y_filtred.append(rtab_y[i])
        rtab_t_filtred.append(rtab_t[i])

# %%
from scipy.interpolate import interp1d
fx = interp1d(hector_t, hector_x)
fy = interp1d(hector_t, hector_y)

# %%
n1 = 554
n2 = 972

rtab_x_data = []
rtab_y_data = []
rtab_t_data = []

rtab_x_data[:] = rtab_x_filtred[:n2] 
rtab_y_data[:] = rtab_y_filtred[:n2]
rtab_t_data[:] = rtab_t_filtred[:n2]

# %%
point = n1+1
x_shift = fx(rtab_t_filtred[point])
y_shift = fy(rtab_t_filtred[point])

# %%
alpha =  -0.07
rtab_x_r = []
rtab_y_r = []

rtab_x_r[:] = rtab_x_data[:]
rtab_y_r[:] = rtab_y_data[:]

for i in np.arange(n1,n2):
    rtab_x_r[i] =  np.cos(alpha) * rtab_x_data[i] + np.sin(alpha) * rtab_y_data[i]
    rtab_y_r[i] = -np.sin(alpha) * rtab_x_data[i] + np.cos(alpha) * rtab_y_data[i]

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(rtab_x_r,rtab_y_r, label= "RTAB-map pose")
plt.plot(hector_x, hector_y, label= "Hector SLAM_pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
rtab_x_opt = []
rtab_y_opt = []

rtab_x_opt[:] = rtab_x_r[:]
rtab_y_opt[:] = rtab_y_r[:]

for i in np.arange(n1,n2):
    rtab_x_opt[i] = rtab_x_r[i] + x_shift.max()
    rtab_y_opt[i] = rtab_y_r[i] + y_shift.max()

# %%
rtab_x_opt_s = np.array(rtab_x_opt)
rtab_x_opt_s = rtab_x_opt_s + 0.33

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(rtab_x_opt_s,rtab_y_opt, label= "RTAB-map pose")
plt.plot(hector_x, hector_y, label= "Hector SLAM pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
plt.figure(figsize=(width,width))
plt.title("Robot trajectory")
plt.plot(rtab_x_opt_s,rtab_y_opt, label= "RTAB map \n trajectory")
plt.plot(hector_x, hector_y, label= "Hector SLAM \n trajectory")
plt.axis('equal')
plt.grid(linestyle='dotted')
plt.xlabel("Position x (m)", fontsize=12)
plt.ylabel("Position y (m)", fontsize=12)
plt.legend(loc =10, fontsize = 8, framealpha=1)
plt.savefig('./images/zed/rtabmap.png', bbox_inches='tight', format='png', dpi=600)
plt.show()

# %%
ate(hector_x, hector_y,hector_t,rtab_x_opt_s,rtab_y_opt,rtab_t_data, "zed/atertabHect.png")
# Out:
# ('RMSE: ', 0.16330698563758808)
# ('min: ', 0.0041474754964634045)
# ('max: ', 0.34910422327415186)
# ('median: ', 0.11001912852942722)
# ('mean: ', 0.13892678242545245)
# ('std: ', 0.08584008785495499)
# ('var: ', 0.007368520682946392)

# %% [markdown]
# # S-PTAM

# %%
import rospkg
rospack = rospkg.RosPack()
sptam_path= dataset_path + '/zed/sptam/2018-05-03-19-30-09.bag'
#sptam_path= dataset_path + '/zed/sptam/2018-05-03-19-19-02.bag'
print(sptam_path)
# Out:
# ./../datasets//zed/sptam/2018-05-03-19-30-09.bag

# %%
getInfoAboutBag(sptam_path)
# Out:
# ['/sptam/robot/pose']
# ['geometry_msgs/PoseWithCovarianceStamped']

# %%
bag = rosbag.Bag(sptam_path)
sptam_poses = []
for topic, msg, t in bag.read_messages(topics=['/sptam/robot/pose']):
    sptam_poses.append(msg)
bag.close()

# %%
print(np.shape(sptam_poses))
# Out:
# (1185,)

# %%
sptam_x = []
sptam_y = []
sptam_t = []

for odom in sptam_poses:
    sptam_x.append(odom.pose.pose.position.z)
    sptam_y.append(-1 * odom.pose.pose.position.x)
    sptam_t.append(getTime(odom))

# %%
sptam_t_glob = np.array(sptam_t)
sptam_t = timeShift(sptam_t_glob, start_time)

sptam_x_opt = np.array(sptam_x)
sptam_x_opt[:] = sptam_x_opt[:] + 0.325

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(sptam_x_opt,sptam_y, label= "S-PTAM pose")
plt.plot(hector_x, hector_y, label= "Hector SLAM pose")
plt.axis('equal')
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 10)
plt.show()

# %%
plt.figure(figsize=(width,width))
plt.title("Robot trajectory")
plt.plot(sptam_x_opt,sptam_y, label= "S-PTAM \n trajectory")
plt.plot(hector_x, hector_y, label= "Hector SLAM \n trajectory")
plt.axis('equal')
plt.grid(linestyle='dotted')
plt.xlabel("Position x (m)", fontsize=12)
plt.ylabel("Position y (m)", fontsize=12)
plt.legend(loc =10, fontsize = 8, framealpha=1)
plt.savefig('./images/zed/sptam.png', bbox_inches='tight', format='png', dpi=600)
plt.show()

# %%
np.shape(sptam_x_opt)
# Out:
# (1185,)

# %%
sptam_x_opt_cut = np.delete(sptam_x_opt,np.arange(1055,1185))
sptam_y_cut = np.delete(sptam_y,np.arange(1055,1185))
sptam_t_cut = np.delete(sptam_t,np.arange(1055,1185))

# %%
ate(hector_x, hector_y,hector_t,sptam_x_opt_cut,sptam_y_cut,sptam_t_cut, "zed/atesptamnlcHect.png")
# Out:
# ('RMSE: ', 0.3388398753405676)
# ('min: ', 0.00115365864020268)
# ('max: ', 0.7681375883216626)
# ('median: ', 0.24498761189690577)
# ('mean: ', 0.26899527329454476)
# ('std: ', 0.20604369455531643)
# ('var: ', 0.04245400406600453)

# %%
plt.figure(figsize=(5,5))
plt.title("Robot pose")
plt.plot(sptam_t, sptam_x_opt, label= "S-PTAM pose X")
plt.plot(sptam_t, sptam_y, label= "S-PTAM pose Y")
plt.plot(hector_t, hector_x, label= "Hector SLAM pose X")
plt.plot(hector_t, hector_y, label= "Hector SLAM pose Y");
plt.grid()
plt.xlabel("Position x (m)")
plt.ylabel("Position y (m)")
plt.legend(loc = 3)
plt.show()
